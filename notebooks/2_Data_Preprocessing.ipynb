# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../kaggle_dataset/train.csv')

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# checking dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# describe of data
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
# checking null values of dataset and checking total percentage of null value
def check_null(data):
    for feature in data:
        if data[feature].isnull().sum():
            print(f"Total null value in '{feature}': {data[feature].isnull().sum()/len(data[feature])*100}%")
           

check_null(df)
# Out:
# Total null value in 'LotFrontage': 17.73972602739726%
# Total null value in 'Alley': 93.76712328767123%
# Total null value in 'MasVnrType': 0.547945205479452%
# Total null value in 'MasVnrArea': 0.547945205479452%
# Total null value in 'BsmtQual': 2.5342465753424657%
# Total null value in 'BsmtCond': 2.5342465753424657%
# Total null value in 'BsmtExposure': 2.6027397260273974%
# Total null value in 'BsmtFinType1': 2.5342465753424657%
# Total null value in 'BsmtFinType2': 2.6027397260273974%
# Total null value in 'Electrical': 0.0684931506849315%
# Total null value in 'FireplaceQu': 47.26027397260274%
# Total null value in 'GarageType': 5.5479452054794525%
# Total null value in 'GarageYrBlt': 5.5479452054794525%
# Total null value in 'GarageFinish': 5.5479452054794525%
# Total null value in 'GarageQual': 5.5479452054794525%
# Total null value in 'GarageCond': 5.5479452054794525%
# Total null value in 'PoolQC': 99.52054794520548%
# Total null value in 'Fence': 80.75342465753424%
# ...

# %% [markdown]
# - there are some columns with more than 80% of null values we can drop this columns

# %%
# with list comprehension we drop columns that have more than 90% of null values
[df.drop(feature,inplace=True, axis=1) for feature in df if df[feature].isnull().sum()/len(df[feature])*100 >= 80.0 ]
# Out:
# [None, None, None, None]

# %%
# drop id column
df.drop('Id',axis=1, inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0          60       RL         65.0     8450   Pave      Reg         Lvl
# 1          20       RL         80.0     9600   Pave      Reg         Lvl
# 2          60       RL         68.0    11250   Pave      IR1         Lvl
# 3          70       RL         60.0     9550   Pave      IR1         Lvl
# 4          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 0    AllPub    Inside       Gtl  ...             0         0           0
# 1    AllPub       FR2       Gtl  ...             0         0           0
# 2    AllPub    Inside       Gtl  ...             0         0           0
# 3    AllPub    Corner       Gtl  ...           272         0           0
# 4    AllPub       FR2       Gtl  ...             0         0           0
#
#   PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# ...

# %%
# fire treat categorical columns null value
categorical_nan = [feature for feature in df.columns if df[feature].dtypes=="O" and df[feature].isnull().sum()>=1]

# %%
for i in df[categorical_nan]:
    print(df[i].value_counts())
    print('-----------------------------------------')
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
# -----------------------------------------
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
# -----------------------------------------
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
# -----------------------------------------
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
# -----------------------------------------
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64
# -----------------------------------------
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: BsmtFinType2, dtype: int64
# -----------------------------------------
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: Electrical, dtype: int64
# -----------------------------------------
# ...

# %% [markdown]
# - temporary we fill nan value in categorical features with "missing"

# %%
df[categorical_nan] = df[categorical_nan].fillna('missing')

# %%
df[categorical_nan].isnull().sum()
# Out:
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# Electrical      0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %% [markdown]
# - fill numerical feature with median. because in this dataset there are more outlliers so we will not use mean

# %%
numerical_nan = [feature for feature in df.columns if df[feature].isnull().sum()>=1 and df[feature].dtypes!="O"]

# %%
numerical_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
## Replacing the numerical Missing Values

for feature in numerical_nan:
    ## We will replace by using median since there are outliers
    median_value=df[feature].median()
    print(f"median for {feature} is = {median_value}")
    ## create a new feature to capture nan values
#    dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
    df[feature].fillna(median_value,inplace=True)
# Out:
# median for LotFrontage is = 69.0
# median for MasVnrArea is = 0.0
# median for GarageYrBlt is = 1980.0

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtypes=='O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
# here we do label encoding to transfer categorical values to numerical value
for feature in categorical_features:
    labels_ordered=df.groupby([feature])['SalePrice'].mean().sort_values().index
    labels_ordered={k:i for i,k in enumerate(labels_ordered,0)}
    df[feature]=df[feature].map(labels_ordered)

# %%
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0     8450       1         0
# 1             20         3         80.0     9600       1         0
# 2             60         3         68.0    11250       1         1
# 3             70         3         60.0     9550       1         1
# 4             60         3         84.0    14260       1         1
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0     7917       1         0
# 1456          20         3         85.0    13175       1         0
# 1457          70         3         66.0     9042       1         0
# 1458          20         3         68.0     9717       1         0
# 1459          20         3         75.0     9937       1         0
#
#       LandContour  Utilities  LotConfig  LandSlope  ...  EnclosedPorch  \
# 0               1          1          0          0  ...              0
# ...

# %% [markdown]
# - now our data transfer to numerical value

# %%
np.where(df.isnull())
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
categorical_features1 = [feature for feature in df.columns if df[feature].dtypes=='O']
categorical_features1
# Out:
# []

# %%
df.to_csv('final.csv', index=False)
